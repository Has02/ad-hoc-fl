# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
log_path = "logs"

# %%
experiment_old_num = 1
experiment_new_num = 3
log_file_old = log_path + "/log_exp" + str(experiment_old_num) + "_run1.csv"
log_file_new = log_path + "/log_exp" + str(experiment_new_num) + "_run1.csv"

# %%
experiment_old_num_non = 2
experiment_new_num_non = 4
log_file_old_non = log_path + "/log_exp" + str(experiment_old_num_non) + "_run1.csv"
log_file_new_non = log_path + "/log_exp" + str(experiment_new_num_non) + "_run1.csv"

# %%
acc_data_old_non = pd.read_csv(log_file_old_non, header=0)
acc_data_new_non = pd.read_csv(log_file_new_non, header=0)

# %%
acc_data_old = pd.read_csv(log_file_old, header=0)
acc_data_new = pd.read_csv(log_file_new, header=0)
acc_data_old
# Out:
#     CommRound    acc      loss
# 0           0  10.19  4.924666
# 1           1  10.19  4.924666
# 2           2  90.74  0.368814
# 3           3  90.74  0.368814
# 4           4  96.00  0.135237
# 5           5  96.00  0.135237
# 6           6  96.67  0.113737
# 7           7  96.67  0.113737
# 8           8  97.04  0.098962
# 9           9  97.04  0.098962
# 10         10  97.35  0.088717
# 11         11  97.35  0.088717
# 12         12  97.54  0.080456
# 13         13  97.54  0.080456
# 14         14  97.68  0.074756
# 15         15  97.68  0.074756
# 16         16  97.88  0.070124
# 17         17  97.88  0.070124
# 18         18  98.03  0.066278
# 19         19  98.03  0.066278
# 20         20  98.08  0.063225
# 21         21  98.08  0.063225
# 22         22  98.12  0.060623
# 23         23  98.12  0.060623
# 24         24  98.21  0.058548
# 25         25  98.21  0.058548
# 26         26  98.28  0.056628
# 27         27  98.28  0.056628
# 28         28  98.28  0.055128
# 29         29  98.28  0.055128
# 30         30  98.34  0.053874
# 31         31  98.34  0.053874
# 32         32  98.37  0.052410
# 33         33  98.37  0.052410
# 34         34  98.42  0.051180
# 35         35  98.42  0.051180
# 36         36  98.45  0.050116
# 37         37  98.45  0.050116
# 38         38  98.45  0.049389
# 39         39  98.45  0.049389
# 40         40  98.49  0.048383
# 41         41  98.49  0.048383
# 42         42  98.51  0.047725
# 43         43  98.51  0.047725
# 44         44  98.51  0.047181
# 45         45  98.51  0.047181
# 46         46  98.53  0.046647
# 47         47  98.53  0.046647
# 48         48  98.56  0.046054
# 49         49  98.56  0.046054
# 50         50  98.61  0.045703

# %%
times_file = log_path + "/round_times.csv"
times_data = pd.read_csv(times_file, header=0)

times_data
# Out:
#   experiment                                                  0  \
# 0       exp1  [7.90111231803894,6.839287996292114,6.90122413...
# 1       exp2  [7.935397386550903,6.790805101394653,6.7834181...
# 2       exp3  [7.990232706069946,6.924022436141968,7.0259537...
# 3       exp4  [7.965578317642212,6.771423578262329,6.6881039...
#
#                                                    1  \
# 0  [7.929113388061523,6.794774293899536,6.9067342...
# 1  [8.183469772338867,7.038506507873535,7.0285108...
# 2  [7.65317177772522,6.742948532104492,7.02294969...
# 3  [7.973327875137329,6.7231457233428955,6.668098...
#
#                                                    2  \
# 0  [7.9581146240234375,6.768407821655273,6.843224...
# 1  [8.11704969406128,6.815131664276123,6.97855353...
# 2  [8.248234987258911,6.844984769821167,6.9959533...
# 3  [7.8201987743377686,6.781741142272949,6.855629...
# 2  [4.443785667419434,4.281884431838989,4.5520989...
# 3  [4.283400535583496,4.405941009521484,4.3148016...
#
#                                                   97  \
# 0  [4.413964033126831,4.42316746711731,4.38403177...
# 1  [4.552358627319336,4.494210481643677,4.5541045...
# 2  [4.435788869857788,4.401892900466919,4.4345817...
# 3  [4.289400577545166,4.418724298477173,4.3498001...
#
#                                                   98  \
# 0  [4.355442523956299,4.382162809371948,4.3335173...
# 1  [4.419207334518433,4.405635833740234,4.4945292...
# 2  [4.5313026905059814,4.363403081893921,4.414582...
# 3  [5.054269695281982,5.161599540710449,5.0631388...
#
#                                                   99
# 0  [4.350398778915405,4.37816047668457,4.39903187...
# 1  [4.4751787185668945,4.389118671417236,4.419813...
# 2  [4.474787712097168,4.319886207580566,4.4895815...
# 3  [4.247889518737793,4.394591569900513,4.2662842...
#
# [4 rows x 101 columns]

# %%
# Just change index to the experiments you want to plot
experiment_old = 0
experiment_new = 2

old_data = times_data.iloc[experiment_old]
new_data = times_data.iloc[experiment_new]

# drop first row
old_data = old_data.drop(old_data.index[0])
new_data = new_data.drop(new_data.index[0])

# %%
experiment_old_non = 1
experiment_new_non = 3

old_data_non = times_data.iloc[experiment_old_non]
new_data_non = times_data.iloc[experiment_new_non]

# drop first row
old_data_non = old_data_non.drop(old_data_non.index[0])
new_data_non = new_data_non.drop(new_data_non.index[0])

# %%
old_data
# Out:
# 0     [7.90111231803894,6.839287996292114,6.90122413...
# 1     [7.929113388061523,6.794774293899536,6.9067342...
# 2     [7.9581146240234375,6.768407821655273,6.843224...
# 3     [7.84859561920166,6.840771675109863,6.82870650...
# 4     [8.040631771087646,6.960803270339966,6.9357450...
#                             ...
# 95    [4.312391519546509,4.331163167953491,4.2169952...
# 96    [4.330392599105835,4.42667818069458,4.40503931...
# 97    [4.413964033126831,4.42316746711731,4.38403177...
# 98    [4.355442523956299,4.382162809371948,4.3335173...
# 99    [4.350398778915405,4.37816047668457,4.39903187...
# Name: 0, Length: 100, dtype: object

# %%
old_data.iloc[0]
# Out:
# '[8.224797248840332,7.057028770446777,7.326509952545166,7.0577216148376465,7.115507364273071,7.068936109542847,7.050628900527954,7.059066534042358,7.039617300033569,7.134092807769775,]'

# %%
import ast
# in the second column, there is a string that needs to be converted to a list
# this is for each row in the dataframe
for i in range(len(old_data)):
    old_data.iloc[i] = ast.literal_eval(old_data.iloc[i])

for i in range(len(new_data)):
    new_data.iloc[i] = ast.literal_eval(new_data.iloc[i])

# %%
# in the second column, there is a string that needs to be converted to a list
# this is for each row in the dataframe
for i in range(len(old_data_non)):
    old_data_non.iloc[i] = ast.literal_eval(old_data_non.iloc[i])

for i in range(len(new_data_non)):
    new_data_non.iloc[i] = ast.literal_eval(new_data_non.iloc[i])

# %%
old_data
# Out:
# 0     [7.90111231803894, 6.839287996292114, 6.901224...
# 1     [7.929113388061523, 6.794774293899536, 6.90673...
# 2     [7.9581146240234375, 6.768407821655273, 6.8432...
# 3     [7.84859561920166, 6.840771675109863, 6.828706...
# 4     [8.040631771087646, 6.960803270339966, 6.93574...
#                             ...
# 95    [4.312391519546509, 4.331163167953491, 4.21699...
# 96    [4.330392599105835, 4.42667818069458, 4.405039...
# 97    [4.413964033126831, 4.42316746711731, 4.384031...
# 98    [4.355442523956299, 4.382162809371948, 4.33351...
# 99    [4.350398778915405, 4.37816047668457, 4.399031...
# Name: 0, Length: 100, dtype: object

# %%
# There are 100 rows in the dataframe, each row is a device
# The first column is the device index
# The second column is the list of times for each round
# So, the list of times appends a new time for each round to the list

# I want to get the max time for each round over all the devices
# So, I will create a new list of times, where each element is the max time for that round
# Then, I will plot this list

max_times_old = []
max_times_new = []

for i in range(50):
    els_old = old_data.apply(lambda x: x[i])
    els_new = new_data.apply(lambda x: x[i])
    max_times_old.append(max(els_old.values))
    max_times_new.append(max(els_new.values))

# %%
max_times_old_non = []
max_times_new_non = []

for i in range(50):
    els_old_non = old_data_non.apply(lambda x: x[i])
    els_new_non = new_data_non.apply(lambda x: x[i])
    max_times_old_non.append(max(els_old_non.values))
    max_times_new_non.append(max(els_new_non.values))

# %%
max_times_old
# Out:
# [8.068150043487549,
#  6.960803270339966,
#  6.967736482620239,
#  7.002845287322998,
#  7.023879051208496,
#  6.9940879344940186,
#  7.054235458374023,
#  7.014074802398682,
#  6.977997064590454,
#  7.062008857727051,
#  6.920301675796509,
#  6.9854960441589355,
#  7.036740779876709,
#  6.985016584396362,
#  7.017106056213379,
#  6.99635124206543,
#  6.994425296783447,
#  6.999942064285278,
#  6.950558662414551,
#  6.927798509597778,
#  6.918505668640137,
#  6.929986238479614,
#  6.96995735168457,
#  7.0090813636779785,
#  6.969997882843018,
#  6.953038930892944,
#  6.955324649810791,
#  7.047273635864258,
#  7.009277582168579,
#  6.917469024658203,
#  6.943628311157227,
#  6.930086135864258,
#  6.982208728790283,
#  6.920040130615234,
#  6.931047439575195,
#  6.9480977058410645,
#  6.995840549468994,
#  7.011974334716797,
#  6.982588052749634,
#  7.005374908447266,
#  6.990156173706055,
#  6.999402761459351,
#  6.970976829528809,
#  6.920053720474243,
#  7.362522840499878,
#  7.035107135772705,
#  6.992469787597656,
#  7.064188480377197,
#  7.08688497543335,
#  7.02743124961853]

# %%
max_times_new
# Out:
# [9.887084770202636,
#  8.350247383117676,
#  8.460536670684814,
#  8.396333026885985,
#  8.510054397583007,
#  8.50750207901001,
#  8.500018215179443,
#  8.60430507659912,
#  8.415685844421386,
#  8.578004550933837,
#  8.477877330780029,
#  8.503535842895507,
#  8.496539497375489,
#  8.587730026245117,
#  8.664717006683349,
#  8.47391538619995,
#  8.422727108001709,
#  8.519607639312744,
#  8.440334129333495,
#  8.470464992523192,
#  8.500045680999756,
#  8.461877346038818,
#  8.419944190979004,
#  8.942385864257812,
#  8.550514698028564,
#  8.621214294433594,
#  8.615469360351563,
#  8.577429485321044,
#  8.589656925201416,
#  8.502161121368408,
#  8.602864837646484,
#  8.49535846710205,
#  8.505177783966063,
#  8.537255573272704,
#  8.50006399154663,
#  8.43116111755371,
#  8.46595287322998,
#  8.464794158935547,
#  8.418853855133056,
#  8.54538631439209,
#  8.372729301452637,
#  8.51552209854126,
#  8.474013805389404,
#   78.55917501  85.59397888  92.64727449  99.72027445 106.75717115
#  113.81684446 120.83294678 127.87489676 134.96945143 142.04431748
#  149.31936765 156.34154987 163.45371652 170.56731248 177.63401484
#  184.63785195 191.71068716 198.81385612 205.82671452 212.87550449
#  219.97566199 227.0281496  234.08583832 241.16201568 248.24866939
#  255.3556757  262.42469263 269.42132092 276.47514796 283.59046268
#  290.69178009 297.7864151  304.82506514 311.89963412 318.89793229
#  326.08085537 333.19693947 340.18487763 347.36010361 354.4260397 ]
# Total time new:  [  9.80001698  17.93798761  26.27696486  34.50658751  42.76722336
#   51.04289646  59.17778406  67.58546619  75.91470022  84.41195927
#   92.83892784 101.21290827 109.57168579 118.0016819  126.26895504
#  134.50539265 142.81856403 151.14029818 159.39522943 167.67874002
#  176.0486475  184.51586666 193.04629698 201.40218287 209.83153467
#  218.18178949 226.49355354 234.89251986 243.21248331 251.59545937
#  260.03292761 268.38585548 276.84157391 285.10119066 293.43900261
#  301.92547474 310.30770664 318.70171394 327.02238178 335.5827404
#  343.98089705 352.30576172 360.74718533 369.004105   377.36105375
#  385.61329308 393.96142302 402.28188    410.62281561 418.88056898]

# %%
# push 0 to the beginning of the list for max times
max_times_old.insert(0, 0)
max_times_new.insert(0, 0)

# %%
# push 0 to the beginning of the list for max times
max_times_old_non.insert(0, 0)
max_times_new_non.insert(0, 0)

# %%
plot_times_old = np.cumsum(max_times_old)
plot_times_new = np.cumsum(max_times_new)

# %%
plot_times_old_non = np.cumsum(max_times_old_non)
plot_times_new_non = np.cumsum(max_times_new_non)

# %%
# times are the x axis stored in the max_times_old list and max_times_new list
# accuracies are the y axis stored in the acc_data_old and acc_data_new dataframes
# I will plot the accuracies against the times

plt.plot(plot_times_old, acc_data_old['acc'], label='Homogeneity')
plt.plot(plot_times_new, acc_data_new['acc'], label='Heterogeneity')
plt.plot(plot_times_old_non, acc_data_old_non['acc'], label='Homogeneity - Non IID')
plt.plot(plot_times_new_non, acc_data_new_non['acc'], label='Heterogeneity - Non IID')
plt.xlabel('Time (seconds)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Time')
plt.grid()
plt.legend()
plt.show()

# %%
# get average time per round
average_time_old = np.mean(max_times_old)
average_time_new = np.mean(max_times_new)

average_time_old_non = np.mean(max_times_old_non)
average_time_new_non = np.mean(max_times_new_non)

print("Average time old: ", average_time_old)
print("Average time new: ", average_time_new)

print("Average time old non: ", average_time_old_non)
print("Average time new non: ", average_time_new_non)
# Out:
# Average time old:  6.876853877422857
# Average time new:  8.364811829959644
# Average time old non:  6.949530190112544
# Average time new non:  8.213344489826875

# %%
# plot total loss vs time
plt.plot(total_time_old, acc_data_old['loss'][1:], label='Homogeneous')
plt.plot(total_time_new, acc_data_new['loss'][1:], label='Heterogeneity')
plt.plot(total_time_old_non, acc_data_old_non['loss'][1:], label='Homogeneous - Non IID')
plt.plot(total_time_new_non, acc_data_new_non['loss'][1:], label='Heterogeneity - Non IID')
plt.xlabel('Time (seconds)')
plt.ylabel('Total Loss')
plt.title('Total Loss vs Time')
plt.legend()
plt.grid()
plt.show()
