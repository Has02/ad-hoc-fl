# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
log_path = "logs"

# %%
experiment = input("Enter experiment number: ")
log_file = log_path + "/log_exp" + experiment + "_run1.csv"

# %%
acc_data = pd.read_csv(log_file, header=0)
acc_data
# Out:
#     CommRound    acc      loss
# 0           0  10.19  4.924654
# 1           1  10.19  4.924654
# 2           2  90.81  0.372406
# 3           3  90.81  0.372406
# 4           4  95.93  0.135860
# 5           5  95.93  0.135860
# 6           6  96.64  0.113503
# 7           7  96.64  0.113503
# 8           8  97.01  0.099377
# 9           9  97.01  0.099377
# 10         10  97.38  0.088535

# %%
times_file = log_path + "round_times.csv"
